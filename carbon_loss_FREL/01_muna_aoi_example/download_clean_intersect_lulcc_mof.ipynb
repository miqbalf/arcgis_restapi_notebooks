# %%
import sys
# !{sys.executable} -m pip install xlrd

# %%
import pandas as pd
import os
import re

import arcpy
import pandas as pd
import geopandas as gpd

import json
# import asyncio
# import httpx

# %%
# name
project_name = 'muna'

# %%
## arcgis project setup load
aprx = arcpy.mp.ArcGISProject('CURRENT')
print([m.name for m in aprx.listMaps()])
# Out:
# ['gps', 'sra']

# %%
# setup map layer interaction arcpy
m = [m for m in aprx.listMaps() if m.name == 'sra'][0]

# check the list layers
print([l.name for l in m.listLayers()])
# Out:
# ['output_json_PL_2024_merge_Clipped_muna_dis', 'output_json_PL_2024_merge_Clipped_muna', 'output_json_PL_2023_merge_Clipped_muna_dis', 'output_json_PL_2023_merge_Clipped_muna', 'PL_2019_Clipped_muna_dis', 'PL_2019_Clipped_muna', 'PL_2018_Clipped_muna_dis', 'PL_2018_Clipped_muna', 'PL_2017_Clipped_muna_dis', 'PL_2017_Clipped_muna', 'PL_2022_Clipped_muna_dis', 'PL_2022_Clipped_muna', 'PL_2021_Clipped_muna_dis', 'PL_2021_Clipped_muna', 'PL_2020_Clipped_muna_dis', 'PL_2020_Clipped_muna', 'PL_2016_Clipped_muna_dis', 'PL_2016_Clipped_muna', 'PL_2015_Clipped_muna_dis', 'PL_2015_Clipped_muna', 'PL_2014_Clipped_muna_dis', 'PL_2014_Clipped_muna', 'PL_2013_Clipped_muna_dis', 'PL_2013_Clipped_muna', 'PL_2012_Clipped_muna_dis', 'PL_2012_Clipped_muna', 'PL_2011_Clipped_muna_dis', 'PL_2011_Clipped_muna', 'PL_2009_Clipped_muna_dis', 'PL_2009_Clipped_muna', 'PL_2006_Clipped_muna_dis', 'PL_2006_Clipped_muna', 'PL_2003_Clipped_muna_dis', 'PL_2003_Clipped_muna', 'PL_2000_Clipped_muna_dis', 'PL_2000_Clipped_muna', 'PL_1996_Clipped_muna_dis', 'PL_1996_Clipped_muna', 'PL_1990_Clipped_muna_dis', 'PL_1990_Clipped_muna', 'output_json_PL_2024_merge', 'output_json_PL_2023_merge', 'PL_2023_oid_14_JSONd', 'PL_2023_oid_14_JSONToFeature', 'LC_MoF_1990_2022_muna_cleaned', 'LC_MoF_1990_2022_muna_dissolved', 'LC_MoF_1990_2022_muna', 'analysis_lulc', 'plotSRA_treeocloud_20250714', 'AOI_SRA_plots', 'AOI_SRA_BIG', 'project_area_final_old_analysis', 'WWF Basemap English GLOBIL', 'World Hillshade']

# %%
# the original workspace location
scratch_local_folder = r'\\Mac\Home\Documents\ArcGIS\Projects\treeo_analysis\treeo_analysis.gdb'
# arcpy.env.workspace = scratch_local_folder # later do this again if needed to list the result

#location of downloader webgis
workspace_downloader = r'\\Mac\Home\Documents\arcgis_restapi_notebooks\webgis_downloader'

# %%
# list data webgis MoF downloaded and converted to .gdb
mof_gdb_path = r'F:\gis_data\Timeseries.gdb'
arcpy.env.workspace = mof_gdb_path  # this should be overrided to scratch db again

arcpy.ListFeatureClasses()
# Out:
# ['DEF_2003_2006',
#  'DEF_2006_2009',
#  'DEF_2009_2011',
#  'DEF_2011_2012',
#  'DEF_2012_2013',
#  'DEF_2013_2014',
#  'DEF_2014_2015',
#  'DEF_2015_2016',
#  'DEF_2016_2017',
#  'DEF_2017_2018',
#  'DEF_2018_2019',
#  'DEF_2019_2020',
#  'DEF_2020_2021',
#  'DEF_2021_2022',
#  'PL_1990',
#  'PL_1996',
#  'PL_2000',
#  'PL_2003',
#  'PL_2006',
#  'PL_2009',
#  'PL_2011',
#  'PL_2012',
#  'PL_2013',
#  'PL_2014',
#  'PL_2015',
#  'PL_2016',
#  'PL_2020',
#  'PL_2021',
#  'PL_2022',
#  'REF_2017_2018',
#  'REF_2018_2019',
#  'REF_2019_2020',
#  'REF_2020_2021',
#  'REF_2021_2022',
#  'PL_2017',
#  'PL_2018',
#  'PL_2019']

# %%
## now we are going to update the 2023 and 2024 data LC!
# redownload from webgis of MoF

# define AOI to download first, no need entire country to download
# this AOI will be converted to rectangle, bbox extent
# shapefile name for input, to get boundary aoi
aoi_bbox_to_download = r'Z:\Shared drives\TREEO BD Supply\satellite_verification\2025_notebooks_Satver\20250714_SRA_recheck_baseline\00_input\AOI_SRA_BIG.shp'
geometry_type = 'POLYGON'

# description, properties of layer bbox
desc = arcpy.Describe(aoi_bbox_to_download)

# envelope bbox for arcgis rest api
envelope = desc.extent

print('envelope :',envelope)
xmin, ymin, xmax, ymax = envelope.XMin, envelope.YMin, envelope.XMax, envelope.YMax
print(xmax)

# make a new name json, for scrapy input
json_file_name = f'bbox_{project_name}.json'

# adding path and defined, use hardcoded instead
json_file_path = os.path.join(workspace_downloader,'input_json',json_file_name)

# implementation -> conversion to json for bbox
data_bbox = {}
data_bbox['xmin'] = xmin
data_bbox['ymin'] = ymin
data_bbox['xmax'] = xmax
data_bbox['ymax'] = ymax


# dictionary to json file
with open(json_file_path, 'w') as json_file:
    json.dump(data_bbox, json_file)

print(data_bbox)

## AFTER EDITED in spider, to put in spatial envelope, let's run the command scrapy and check
print(f'''
# RUN THIS COMMAND IN ROOT, NOT IN THIS JUPYTER, in the folder that has scrapy.cfg file
# scrapy crawl webgis_klhk_spider -O {json_file_name.replace(".json","")}_oid_list.json or you later change the naming
# {json_file_name.replace(".json","")}_oid_list.json contains objectids that needed for request
''')
# Out:
# envelope : 122.486941248724 -5.18526909734851 122.662877794137 -4.93236031331837 NaN NaN NaN NaN
# 122.66287779413656
# {'xmin': 122.48694124872429, 'ymin': -5.185269097348513, 'xmax': 122.66287779413656, 'ymax': -4.9323603133183695}
#
# # RUN THIS COMMAND IN ROOT, NOT IN THIS JUPYTER, in the folder that has scrapy.cfg file
# # scrapy crawl webgis_klhk_spider -O bbox_muna_oid_list.json or you later change the naming
# # bbox_muna_oid_list.json contains objectids that needed for request

# %%
scratch_folder = r"\\Mac\\Home\\Documents\\ArcGIS\\Projects\\treeo_analysis\\"

# %%
### DO NOT DO IT AGAIN IF YOU ALREADY DONE THIS!
# list all the neccessary feature class
time_series_old = arcpy.ListFeatureClasses() # based on above env
# print([l for l in time_series_old])

#process the json collection based on the list data from the above (SCRAPY)
import os

# scratch folder output conversion json
scratch_folder = r"\\Mac\Home\Documents\ArcGIS\Projects\treeo_analysis\"

# Define the path to the root folder you want to search
root_directory = r'C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\'

# Iterate through all directories and files recursively
list_output_lulc = []
for dirpath, dirnames, filenames in os.walk(root_directory):
    # dirpath is the path to the current directory
    # dirnames is a list of subdirectories in the current directory
    # filenames is a list of files in the current directory
    if 'output' in os.path.basename(dirpath):
        print('\n------------------------------------------------------')
        print(dirpath)

        folder_name = os.path.basename(dirpath)

        arcpy.management.CreateFileGDB(
            out_folder_path=scratch_folder, # put it in scratch folder
            out_name=folder_name, # make the same name
            out_version="CURRENT"
        )

        output_gdb = os.path.join(scratch_folder, folder_name+'.gdb')

        arcpy.env.addOutputsToMap = False
        # Iterate over the files in the current directory
        list_file = [] # initiate the empty list files every directory in dirpath (that filtered 'output')
        for filename in filenames:
            # Construct the full file path
            file_path = os.path.join(dirpath, filename)
    
            file_name = os.path.basename(file_path)

            output_file = os.path.join(output_gdb,file_name.replace('.json',''))
    
            if 'oid' in file_name:
                # Now you can process the file
                print(f"Found file: {file_path}")
                #list_file.append(file_path)
                arcpy.conversion.JSONToFeatures(
                    in_json_file=file_path,
                    out_features=output_file, # makesure, no extension for feature class in gdb
                    geometry_type="POLYGON" # lets hardcoded for now this part, later if we want to convert the line, point json, then revisit this to load json first
                )
                list_file.append(output_file)
                print(f'Done for {file_name}') 

        print('process to merge data')
        # to display the merge data
        arcpy.env.addOutputsToMap = True     
        output_file_merged = os.path.join(output_gdb,folder_name+'_merge')
        arcpy.management.Merge(
            inputs=list_file,
            output=output_file_merged,
            field_mappings=None,
            add_source="NO_SOURCE_INFO",
            field_match_mode="AUTOMATIC"
        )

        list_output_lulc.append(output_file_merged)

        print(f'all done for {folder_name}')
# Out:
# ------------------------------------------------------
# C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_149870.json
# Done for PL_2023_oid_149870.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_149872.json
# Done for PL_2023_oid_149872.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_149873.json
# Done for PL_2023_oid_149873.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_149874.json
# Done for PL_2023_oid_149874.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_149876.json
# Done for PL_2023_oid_149876.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_149877.json
# Done for PL_2023_oid_149877.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_149880.json
# Done for PL_2023_oid_149880.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_149881.json
# Done for PL_2023_oid_149881.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_149884.json
# Done for PL_2023_oid_149884.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_149886.json
# Done for PL_2023_oid_149886.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_149888.json
# Done for PL_2023_oid_149888.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_149889.json
# Done for PL_2023_oid_149889.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_149890.json
# Done for PL_2023_oid_149890.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_149891.json
# Done for PL_2023_oid_149891.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_149892.json
# Done for PL_2023_oid_149892.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_149893.json
# Done for PL_2023_oid_149893.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_149894.json
# Done for PL_2023_oid_149894.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_149895.json
# Done for PL_2023_oid_149895.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_149896.json
# Done for PL_2023_oid_149896.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_149897.json
# Done for PL_2023_oid_149897.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_149903.json
# Done for PL_2023_oid_149903.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151009.json
# Done for PL_2023_oid_151009.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151027.json
# Done for PL_2023_oid_151027.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151034.json
# Done for PL_2023_oid_151034.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151039.json
# Done for PL_2023_oid_151039.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151042.json
# Done for PL_2023_oid_151042.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151043.json
# Done for PL_2023_oid_151043.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151044.json
# Done for PL_2023_oid_151044.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151048.json
# Done for PL_2023_oid_151048.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151050.json
# Done for PL_2023_oid_151050.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151058.json
# Done for PL_2023_oid_151058.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151061.json
# Done for PL_2023_oid_151061.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151069.json
# Done for PL_2023_oid_151069.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151072.json
# Done for PL_2023_oid_151072.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151075.json
# Done for PL_2023_oid_151075.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151078.json
# Done for PL_2023_oid_151078.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151084.json
# Done for PL_2023_oid_151084.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151085.json
# Done for PL_2023_oid_151085.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151090.json
# Done for PL_2023_oid_151090.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151091.json
# Done for PL_2023_oid_151091.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151096.json
# Done for PL_2023_oid_151096.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151097.json
# Done for PL_2023_oid_151097.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151101.json
# Done for PL_2023_oid_151101.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151102.json
# Done for PL_2023_oid_151102.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151103.json
# Done for PL_2023_oid_151103.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151109.json
# Done for PL_2023_oid_151109.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151110.json
# Done for PL_2023_oid_151110.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151112.json
# Done for PL_2023_oid_151112.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151113.json
# Done for PL_2023_oid_151113.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151114.json
# Done for PL_2023_oid_151114.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151115.json
# Done for PL_2023_oid_151115.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151116.json
# Done for PL_2023_oid_151116.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151117.json
# Done for PL_2023_oid_151117.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151119.json
# Done for PL_2023_oid_151119.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151123.json
# Done for PL_2023_oid_151123.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151125.json
# Done for PL_2023_oid_151125.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151126.json
# Done for PL_2023_oid_151126.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151129.json
# Done for PL_2023_oid_151129.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151131.json
# Done for PL_2023_oid_151131.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151136.json
# Done for PL_2023_oid_151136.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151141.json
# Done for PL_2023_oid_151141.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151142.json
# Done for PL_2023_oid_151142.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151143.json
# Done for PL_2023_oid_151143.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151144.json
# Done for PL_2023_oid_151144.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151145.json
# Done for PL_2023_oid_151145.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151148.json
# Done for PL_2023_oid_151148.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151150.json
# Done for PL_2023_oid_151150.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151152.json
# Done for PL_2023_oid_151152.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151153.json
# Done for PL_2023_oid_151153.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151154.json
# Done for PL_2023_oid_151154.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151155.json
# Done for PL_2023_oid_151155.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151160.json
# Done for PL_2023_oid_151160.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151163.json
# Done for PL_2023_oid_151163.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151164.json
# Done for PL_2023_oid_151164.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_151222.json
# Done for PL_2023_oid_151222.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_153281.json
# Done for PL_2023_oid_153281.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_153282.json
# Done for PL_2023_oid_153282.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_153290.json
# Done for PL_2023_oid_153290.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_153303.json
# Done for PL_2023_oid_153303.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_153315.json
# Done for PL_2023_oid_153315.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_153317.json
# Done for PL_2023_oid_153317.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_153325.json
# Done for PL_2023_oid_153325.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_153989.json
# Done for PL_2023_oid_153989.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_154120.json
# Done for PL_2023_oid_154120.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_154122.json
# Done for PL_2023_oid_154122.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_154264.json
# Done for PL_2023_oid_154264.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_154265.json
# Done for PL_2023_oid_154265.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_154266.json
# Done for PL_2023_oid_154266.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_154267.json
# Done for PL_2023_oid_154267.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_154377.json
# Done for PL_2023_oid_154377.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_154382.json
# Done for PL_2023_oid_154382.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_154385.json
# Done for PL_2023_oid_154385.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_154389.json
# Done for PL_2023_oid_154389.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_154391.json
# Done for PL_2023_oid_154391.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_154392.json
# Done for PL_2023_oid_154392.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_154394.json
# Done for PL_2023_oid_154394.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_154399.json
# Done for PL_2023_oid_154399.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_154400.json
# Done for PL_2023_oid_154400.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_154402.json
# Done for PL_2023_oid_154402.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_154405.json
# Done for PL_2023_oid_154405.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_154406.json
# Done for PL_2023_oid_154406.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_154407.json
# Done for PL_2023_oid_154407.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_154409.json
# Done for PL_2023_oid_154409.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_155346.json
# Done for PL_2023_oid_155346.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_155349.json
# Done for PL_2023_oid_155349.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_155351.json
# Done for PL_2023_oid_155351.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_155353.json
# Done for PL_2023_oid_155353.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_155354.json
# Done for PL_2023_oid_155354.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_155359.json
# Done for PL_2023_oid_155359.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_155366.json
# Done for PL_2023_oid_155366.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_155371.json
# Done for PL_2023_oid_155371.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_155372.json
# Done for PL_2023_oid_155372.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_155374.json
# Done for PL_2023_oid_155374.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_155377.json
# Done for PL_2023_oid_155377.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_155378.json
# Done for PL_2023_oid_155378.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_155380.json
# Done for PL_2023_oid_155380.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_155382.json
# Done for PL_2023_oid_155382.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_155383.json
# Done for PL_2023_oid_155383.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_155387.json
# Done for PL_2023_oid_155387.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_155389.json
# Done for PL_2023_oid_155389.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_155391.json
# Done for PL_2023_oid_155391.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_155393.json
# Done for PL_2023_oid_155393.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_155394.json
# Done for PL_2023_oid_155394.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_155398.json
# Done for PL_2023_oid_155398.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_155402.json
# Done for PL_2023_oid_155402.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_155403.json
# Done for PL_2023_oid_155403.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_155408.json
# Done for PL_2023_oid_155408.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_155410.json
# Done for PL_2023_oid_155410.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_155411.json
# Done for PL_2023_oid_155411.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_155416.json
# Done for PL_2023_oid_155416.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_155928.json
# Done for PL_2023_oid_155928.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_155946.json
# Done for PL_2023_oid_155946.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_155951.json
# Done for PL_2023_oid_155951.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_155952.json
# Done for PL_2023_oid_155952.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_155953.json
# Done for PL_2023_oid_155953.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_155954.json
# Done for PL_2023_oid_155954.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_155956.json
# Done for PL_2023_oid_155956.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_155957.json
# Done for PL_2023_oid_155957.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_155961.json
# Done for PL_2023_oid_155961.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_155962.json
# Done for PL_2023_oid_155962.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_155965.json
# Done for PL_2023_oid_155965.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_156070.json
# Done for PL_2023_oid_156070.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_156662.json
# Done for PL_2023_oid_156662.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_157651.json
# Done for PL_2023_oid_157651.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_157679.json
# Done for PL_2023_oid_157679.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_157689.json
# Done for PL_2023_oid_157689.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_157697.json
# Done for PL_2023_oid_157697.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_157700.json
# Done for PL_2023_oid_157700.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_157704.json
# Done for PL_2023_oid_157704.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_157705.json
# Done for PL_2023_oid_157705.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_157709.json
# Done for PL_2023_oid_157709.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_157710.json
# Done for PL_2023_oid_157710.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_157718.json
# Done for PL_2023_oid_157718.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_157727.json
# Done for PL_2023_oid_157727.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_157729.json
# Done for PL_2023_oid_157729.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_157737.json
# Done for PL_2023_oid_157737.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_157738.json
# Done for PL_2023_oid_157738.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_157739.json
# Done for PL_2023_oid_157739.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_157740.json
# Done for PL_2023_oid_157740.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_157744.json
# Done for PL_2023_oid_157744.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_157748.json
# Done for PL_2023_oid_157748.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_157752.json
# Done for PL_2023_oid_157752.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_159061.json
# Done for PL_2023_oid_159061.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_159063.json
# Done for PL_2023_oid_159063.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_159065.json
# Done for PL_2023_oid_159065.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_159066.json
# Done for PL_2023_oid_159066.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_159083.json
# Done for PL_2023_oid_159083.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_159084.json
# Done for PL_2023_oid_159084.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_159087.json
# Done for PL_2023_oid_159087.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_159094.json
# Done for PL_2023_oid_159094.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_159098.json
# Done for PL_2023_oid_159098.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_159099.json
# Done for PL_2023_oid_159099.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_159102.json
# Done for PL_2023_oid_159102.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_159105.json
# Done for PL_2023_oid_159105.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_159106.json
# Done for PL_2023_oid_159106.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_159111.json
# Done for PL_2023_oid_159111.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_159112.json
# Done for PL_2023_oid_159112.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_159113.json
# Done for PL_2023_oid_159113.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_159115.json
# Done for PL_2023_oid_159115.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_160269.json
# Done for PL_2023_oid_160269.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_160300.json
# Done for PL_2023_oid_160300.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_160301.json
# Done for PL_2023_oid_160301.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_160606.json
# Done for PL_2023_oid_160606.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2023\PL_2023_oid_161038.json
# Done for PL_2023_oid_161038.json
# process to merge data
# all done for output_json_PL_2023
#
# ------------------------------------------------------
# C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_357481.json
# Done for PL_2024_oid_357481.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_357483.json
# Done for PL_2024_oid_357483.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_357484.json
# Done for PL_2024_oid_357484.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_357485.json
# Done for PL_2024_oid_357485.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_357489.json
# Done for PL_2024_oid_357489.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_357490.json
# Done for PL_2024_oid_357490.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_357492.json
# Done for PL_2024_oid_357492.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_357495.json
# Done for PL_2024_oid_357495.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_357496.json
# Done for PL_2024_oid_357496.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_357499.json
# Done for PL_2024_oid_357499.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_357501.json
# Done for PL_2024_oid_357501.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_357503.json
# Done for PL_2024_oid_357503.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_357504.json
# Done for PL_2024_oid_357504.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_357505.json
# Done for PL_2024_oid_357505.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_357506.json
# Done for PL_2024_oid_357506.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_357507.json
# Done for PL_2024_oid_357507.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_357508.json
# Done for PL_2024_oid_357508.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_357509.json
# Done for PL_2024_oid_357509.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_357510.json
# Done for PL_2024_oid_357510.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_357511.json
# Done for PL_2024_oid_357511.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_357512.json
# Done for PL_2024_oid_357512.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_357521.json
# Done for PL_2024_oid_357521.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_358942.json
# Done for PL_2024_oid_358942.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_358944.json
# Done for PL_2024_oid_358944.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_358969.json
# Done for PL_2024_oid_358969.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_358979.json
# Done for PL_2024_oid_358979.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_358988.json
# Done for PL_2024_oid_358988.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_358991.json
# Done for PL_2024_oid_358991.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_358993.json
# Done for PL_2024_oid_358993.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_358994.json
# Done for PL_2024_oid_358994.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_358998.json
# Done for PL_2024_oid_358998.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359002.json
# Done for PL_2024_oid_359002.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359015.json
# Done for PL_2024_oid_359015.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359019.json
# Done for PL_2024_oid_359019.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359031.json
# Done for PL_2024_oid_359031.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359032.json
# Done for PL_2024_oid_359032.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359039.json
# Done for PL_2024_oid_359039.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359046.json
# Done for PL_2024_oid_359046.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359047.json
# Done for PL_2024_oid_359047.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359050.json
# Done for PL_2024_oid_359050.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359063.json
# Done for PL_2024_oid_359063.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359064.json
# Done for PL_2024_oid_359064.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359065.json
# Done for PL_2024_oid_359065.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359070.json
# Done for PL_2024_oid_359070.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359072.json
# Done for PL_2024_oid_359072.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359077.json
# Done for PL_2024_oid_359077.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359079.json
# Done for PL_2024_oid_359079.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359082.json
# Done for PL_2024_oid_359082.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359086.json
# Done for PL_2024_oid_359086.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359088.json
# Done for PL_2024_oid_359088.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359089.json
# Done for PL_2024_oid_359089.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359090.json
# Done for PL_2024_oid_359090.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359092.json
# Done for PL_2024_oid_359092.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359097.json
# Done for PL_2024_oid_359097.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359098.json
# Done for PL_2024_oid_359098.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359104.json
# Done for PL_2024_oid_359104.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359105.json
# Done for PL_2024_oid_359105.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359107.json
# Done for PL_2024_oid_359107.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359109.json
# Done for PL_2024_oid_359109.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359110.json
# Done for PL_2024_oid_359110.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359111.json
# Done for PL_2024_oid_359111.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359112.json
# Done for PL_2024_oid_359112.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359113.json
# Done for PL_2024_oid_359113.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359116.json
# Done for PL_2024_oid_359116.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359122.json
# Done for PL_2024_oid_359122.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359124.json
# Done for PL_2024_oid_359124.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359125.json
# Done for PL_2024_oid_359125.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359128.json
# Done for PL_2024_oid_359128.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359129.json
# Done for PL_2024_oid_359129.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359132.json
# Done for PL_2024_oid_359132.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359141.json
# Done for PL_2024_oid_359141.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359145.json
# Done for PL_2024_oid_359145.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359149.json
# Done for PL_2024_oid_359149.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359156.json
# Done for PL_2024_oid_359156.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359158.json
# Done for PL_2024_oid_359158.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359159.json
# Done for PL_2024_oid_359159.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359162.json
# Done for PL_2024_oid_359162.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359163.json
# Done for PL_2024_oid_359163.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359164.json
# Done for PL_2024_oid_359164.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359167.json
# Done for PL_2024_oid_359167.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359169.json
# Done for PL_2024_oid_359169.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359171.json
# Done for PL_2024_oid_359171.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359172.json
# Done for PL_2024_oid_359172.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359173.json
# Done for PL_2024_oid_359173.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359174.json
# Done for PL_2024_oid_359174.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359175.json
# Done for PL_2024_oid_359175.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359176.json
# Done for PL_2024_oid_359176.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359177.json
# Done for PL_2024_oid_359177.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359184.json
# Done for PL_2024_oid_359184.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359187.json
# Done for PL_2024_oid_359187.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359189.json
# Done for PL_2024_oid_359189.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359193.json
# Done for PL_2024_oid_359193.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359195.json
# Done for PL_2024_oid_359195.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359199.json
# Done for PL_2024_oid_359199.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_359298.json
# Done for PL_2024_oid_359298.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_362650.json
# Done for PL_2024_oid_362650.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_362651.json
# Done for PL_2024_oid_362651.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_362690.json
# Done for PL_2024_oid_362690.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_362725.json
# Done for PL_2024_oid_362725.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_362726.json
# Done for PL_2024_oid_362726.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_362728.json
# Done for PL_2024_oid_362728.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_362730.json
# Done for PL_2024_oid_362730.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_362732.json
# Done for PL_2024_oid_362732.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_362759.json
# Done for PL_2024_oid_362759.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_362760.json
# Done for PL_2024_oid_362760.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_362761.json
# Done for PL_2024_oid_362761.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_362764.json
# Done for PL_2024_oid_362764.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_362771.json
# Done for PL_2024_oid_362771.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_362776.json
# Done for PL_2024_oid_362776.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_362777.json
# Done for PL_2024_oid_362777.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_362778.json
# Done for PL_2024_oid_362778.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_362781.json
# Done for PL_2024_oid_362781.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_362784.json
# Done for PL_2024_oid_362784.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_362786.json
# Done for PL_2024_oid_362786.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_362791.json
# Done for PL_2024_oid_362791.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_362792.json
# Done for PL_2024_oid_362792.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_362793.json
# Done for PL_2024_oid_362793.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_362798.json
# Done for PL_2024_oid_362798.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_362804.json
# Done for PL_2024_oid_362804.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_365594.json
# Done for PL_2024_oid_365594.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_365604.json
# Done for PL_2024_oid_365604.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_365605.json
# Done for PL_2024_oid_365605.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_365606.json
# Done for PL_2024_oid_365606.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_365608.json
# Done for PL_2024_oid_365608.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_365609.json
# Done for PL_2024_oid_365609.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_365614.json
# Done for PL_2024_oid_365614.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_365626.json
# Done for PL_2024_oid_365626.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_365627.json
# Done for PL_2024_oid_365627.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_366430.json
# Done for PL_2024_oid_366430.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_366435.json
# Done for PL_2024_oid_366435.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_366438.json
# Done for PL_2024_oid_366438.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_366443.json
# Done for PL_2024_oid_366443.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_366445.json
# Done for PL_2024_oid_366445.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_366446.json
# Done for PL_2024_oid_366446.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_366448.json
# Done for PL_2024_oid_366448.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_366453.json
# Done for PL_2024_oid_366453.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_366454.json
# Done for PL_2024_oid_366454.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_366456.json
# Done for PL_2024_oid_366456.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_366459.json
# Done for PL_2024_oid_366459.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_366460.json
# Done for PL_2024_oid_366460.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_366461.json
# Done for PL_2024_oid_366461.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_366462.json
# Done for PL_2024_oid_366462.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_366464.json
# Done for PL_2024_oid_366464.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_367732.json
# Done for PL_2024_oid_367732.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_367735.json
# Done for PL_2024_oid_367735.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_367737.json
# Done for PL_2024_oid_367737.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_367739.json
# Done for PL_2024_oid_367739.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_367740.json
# Done for PL_2024_oid_367740.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_367745.json
# Done for PL_2024_oid_367745.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_367752.json
# Done for PL_2024_oid_367752.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_367757.json
# Done for PL_2024_oid_367757.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_367758.json
# Done for PL_2024_oid_367758.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_367760.json
# Done for PL_2024_oid_367760.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_367763.json
# Done for PL_2024_oid_367763.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_367764.json
# Done for PL_2024_oid_367764.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_367765.json
# Done for PL_2024_oid_367765.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_367767.json
# Done for PL_2024_oid_367767.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_367769.json
# Done for PL_2024_oid_367769.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_367770.json
# Done for PL_2024_oid_367770.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_367774.json
# Done for PL_2024_oid_367774.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_367776.json
# Done for PL_2024_oid_367776.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_367778.json
# Done for PL_2024_oid_367778.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_367780.json
# Done for PL_2024_oid_367780.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_367781.json
# Done for PL_2024_oid_367781.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_367785.json
# Done for PL_2024_oid_367785.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_367790.json
# Done for PL_2024_oid_367790.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_367791.json
# Done for PL_2024_oid_367791.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_367796.json
# Done for PL_2024_oid_367796.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_367798.json
# Done for PL_2024_oid_367798.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_367799.json
# Done for PL_2024_oid_367799.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_367804.json
# Done for PL_2024_oid_367804.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_368589.json
# Done for PL_2024_oid_368589.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_368611.json
# Done for PL_2024_oid_368611.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_368616.json
# Done for PL_2024_oid_368616.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_368617.json
# Done for PL_2024_oid_368617.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_368618.json
# Done for PL_2024_oid_368618.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_368619.json
# Done for PL_2024_oid_368619.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_368621.json
# Done for PL_2024_oid_368621.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_368622.json
# Done for PL_2024_oid_368622.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_368626.json
# Done for PL_2024_oid_368626.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_368627.json
# Done for PL_2024_oid_368627.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_368630.json
# Done for PL_2024_oid_368630.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_368632.json
# Done for PL_2024_oid_368632.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_368749.json
# Done for PL_2024_oid_368749.json
# Found file: C:\Users\q_bal\Documents\arcgis_restapi_notebooks\webgis_downloader\json_raw\output_json_PL_2024\PL_2024_oid_369520.json
# Done for PL_2024_oid_369520.json
# process to merge data
# all done for output_json_PL_2024

# %%
# list_output_lulc = ['\\\\Mac\\\\Home\\\\Documents\\\\ArcGIS\\\\Projects\\\\treeo_analysis\\\\output_json_PL_2023.gdb\\\\output_json_PL_2023_merge',
#  '\\\\Mac\\\\Home\\\\Documents\\\\ArcGIS\\\\Projects\\\\treeo_analysis\\\\output_json_PL_2024.gdb\\\\output_json_PL_2024_merge']

# %%
prev_data_list = arcpy.ListFeatureClasses() # Timeseries (National data)
# list_output_lulc # is the one that just downloaded from json
prev_data_list = [os.path.join(mof_gdb_path, layername) for layername in prev_data_list]
all_list_data = prev_data_list + list_output_lulc

# %%
# all_list_data

# %%
# all_list_data[0].split('\\')[-1]
os.path.basename(all_list_data[-1])
# Out:
# 'output_json_PL_2024_merge'

# %%
# for i in all_list_data:
#     print(i)

# %%
arcpy.env.overwriteOutput = True
### arcpy analysis in jupyter --> assuming the MoF data is downloaded
# based on the above printed result, the LU data is PL_*
dict_lc_fields = {
    'PL_1990': 'pl90_id',
    'PL_1996': 'pl96_id',
    'PL_2000': 'pl00_id',
    'PL_2003': 'pl03_id',
    'PL_2006': 'pl06_id',
    'PL_2009': 'pl09_id',
    'PL_2011': 'pl11_id',
    'PL_2012': 'pl12_id',
    'PL_2013': 'pl13_id',
    'PL_2014': 'pl14_id',
    'PL_2015': 'pl15_id',
    'PL_2016': 'pl16_id',
    'PL_2017': 'pl17_id',
    'PL_2018': 'PL_18_ID',
    'PL_2019': 'PL_19_R',
    'PL_2020': 'pl2020_id',
    'PL_2021': 'pl2021_id',
    'PL_2022': 'pl2022_id',
     'output_json_PL_2023_merge': 'PL2023_ID',
    'output_json_PL_2024_merge': 'PL2024_ID'
}

for i in all_list_data:
    file_name = os.path.basename(i)
    if 'PL_' in file_name: 
        print(f'processing {file_name}')
        arcpy.analysis.Clip(
            in_features=i,
            clip_features="AOI_SRA_plots",
            out_feature_class=os.path.join(scratch_local_folder,file_name+f'_Clipped_{project_name}'),
            cluster_tolerance=None
        )
        # print(i)

        # dissolving, to clean the data
        arcpy.management.Dissolve(
            in_features=os.path.join(scratch_local_folder,file_name+f'_Clipped_{project_name}'),
            out_feature_class=os.path.join(scratch_local_folder,file_name+f'_Clipped_{project_name}_dis'),
            dissolve_field=dict_lc_fields[file_name],
            statistics_fields=None,
            multi_part="MULTI_PART",
            unsplit_lines="DISSOLVE_LINES",
            concatenation_separator=""
        )
        
    else: # other
        print('other layer: ',file_name)

# %%
# IF ABOVE IS DONE, YOU CAN CONTINUE TO THIS!
# this layer list to include it in group layer
list_to_include_group = [lyr for lyr in m.listLayers() if f'Clipped_{project_name}' in lyr.name ]

group_layer = 'analysis_lulc'

m.createGroupLayer(group_layer)
print(f"Created new group layer: '{group_layer}'")

# --- Get the new group layer object from the map ---
# We find it by name. listLayers returns a list, so we take the first item [0].
group_layer = m.listLayers(group_layer)[0]

# --- Loop through the layers to be grouped and move them ---
for layer_name in list_to_include_group:
    # Find the layer object in the map by its name
    lyr_to_move = m.listLayers(layer_name)[0]
    
    # Use the map's dedicated function to move the layer into the group
    m.addLayerToGroup(group_layer, lyr_to_move)
    m.removeLayer(lyr_to_move)
    # print(f"Moved layer '{layer_name}' into group.")

# change back to default scratch folder
arcpy.env.workspace = scratch_local_folder

# this one for analysis later
list_layers_lc = [lyr for lyr in m.listLayers() if f'Clipped_{project_name}_dis' in lyr.name ]
print(sorted([lyr.name for lyr in list_layers_lc]))

# intersect all the data into single dataset
arcpy.analysis.Intersect(
    in_features=list_layers_lc,
    out_feature_class=r"\\Mac\Home\Documents\ArcGIS\Projects\treeo_analysis\treeo_analysis.gdb\LC_MoF_1990_2024_muna",
    join_attributes="ALL",
    cluster_tolerance=None,
    output_type="INPUT"
)
# Out:
# Created new group layer: 'analysis_lulc'
# ['PL_1990_Clipped_muna_dis', 'PL_1996_Clipped_muna_dis', 'PL_2000_Clipped_muna_dis', 'PL_2003_Clipped_muna_dis', 'PL_2006_Clipped_muna_dis', 'PL_2009_Clipped_muna_dis', 'PL_2011_Clipped_muna_dis', 'PL_2012_Clipped_muna_dis', 'PL_2013_Clipped_muna_dis', 'PL_2014_Clipped_muna_dis', 'PL_2015_Clipped_muna_dis', 'PL_2016_Clipped_muna_dis', 'PL_2017_Clipped_muna_dis', 'PL_2018_Clipped_muna_dis', 'PL_2019_Clipped_muna_dis', 'PL_2020_Clipped_muna_dis', 'PL_2021_Clipped_muna_dis', 'PL_2022_Clipped_muna_dis', 'output_json_PL_2023_merge_Clipped_muna_dis', 'output_json_PL_2024_merge_Clipped_muna_dis']
# <Result '\\\\Mac\\Home\\Documents\\ArcGIS\\Projects\\treeo_analysis\\treeo_analysis.gdb\\LC_MoF_1990_2024_muna'>

# %%
# dissolving, to clean the data
arcpy.management.Dissolve(
    in_features=f"LC_MoF_1990_2024_{project_name}",
    out_feature_class=f"LC_MoF_1990_2024_{project_name}_dissolved",
    dissolve_field=[field for layer,field in dict_lc_fields.items()],
    statistics_fields=None,
    multi_part="MULTI_PART",
    unsplit_lines="DISSOLVE_LINES",
    concatenation_separator=""
)

# calculate area_ha geodesic in the clean data
arcpy.management.CalculateGeometryAttributes(
    in_features=f"LC_MoF_1990_2024_{project_name}_dissolved",
    geometry_property="area_ha AREA_GEODESIC",
    length_unit="",
    area_unit="HECTARES",
    coordinate_system=None,
    coordinate_format="SAME_AS_INPUT"
)
# Out:
# <Result 'LC_MoF_1990_2024_muna_dissolved'>

# %%
# select layer to re-clean the inconsistent (small) area_ha to eliminate (merge) to surround large feature polygon
arcpy.management.SelectLayerByAttribute(
    in_layer_or_view=f"LC_MoF_1990_2024_{project_name}_dissolved",
    selection_type="NEW_SELECTION",
    where_clause="area_ha <= 0.01",
    invert_where_clause=None
)

# cleaning implementation from previous step (select layer)
arcpy.management.Eliminate(
    in_features=f"LC_MoF_1990_2024_{project_name}_dissolved",
    out_feature_class=rf"\\Mac\Home\Documents\ArcGIS\Projects\treeo_analysis\treeo_analysis.gdb\LC_MoF_1990_2024_{project_name}_cleaned",
    selection="LENGTH",
    ex_where_clause="",
    ex_features=None
)
# Out:
# <Result '\\\\Mac\\Home\\Documents\\ArcGIS\\Projects\\treeo_analysis\\treeo_analysis.gdb\\LC_MoF_1990_2024_muna_cleaned'>
